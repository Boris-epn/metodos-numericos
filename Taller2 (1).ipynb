# %% [markdown]
# ## Taller 2

# %% [markdown]
# ## Valor de 100

# %% [markdown]
# Dibujar la ecuación $y(x)=x^3-3x^2+x-1$

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-5, 5, 100)
y = x**3 - 3*x**2 + x - 1
plt.figure(figsize=(8, 6))
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfica de y = x^3 - 3x^2 + x - 1')
plt.grid(True)
plt.show()

# %% [markdown]
# Encontrar la o las raíces usando el método de Newton con Scipy

# %%
from scipy.optimize import newton
def f(x):
    return x**3 - 3*x**2 + x - 1
def fprime(x):
    return 3*x**2-6*x+1
x0 = 100
root = newton(f, x0, fprime=fprime)
print(f'')
print("La raíz aproximada es:", root)
# Out:
# La raíz aproximada es: 2.7692923542386314

# %% [markdown]
# Retornar las estimaciones visitadas por el algoritmo
# * Usando el parámetro args=() u otro método

# %%
points = []
x0 = 100
def f(x: float, points: list[float] = [], show: bool = False):
    y = x**3 - 3 * x**2 + x - 1
    points.append((x, y))
    if show:
        print(f"f({x}) = {y}")
        #pass
    return y
def f_prime(x, *args):
    return 3*x**2-6*x+1
x_r, output = newton(
    f, x0, fprime= f_prime, args=(points, True), maxiter=100, disp= False, full_output= True)
print(output)
x_points = [point[0] for point in points]
plt.figure(figsize=(8, 6))
plt.plot(x_points, "o-", label="x points")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of x points in points")
plt.xlabel("Index")
plt.ylabel("x value")
plt.legend()
plt.show()
# Out:
# f(100.0) = 970099.0
# f(67.00455766810653) = 287421.5546044976
# f(45.009926065596666) = 85151.64374336696
# f(30.35039723527028) = 25223.076156622286
# f(20.582860416480248) = 7468.634520318185
# f(14.079716839009599) = 2209.5053464848224
# f(9.757835905944379) = 652.2076251031732
# f(6.898518561069087) = 191.4272950525605
# f(5.028701696557697) = 55.330187134373084
# f(3.843680657951718) = 15.30811830079546
# f(3.1559707952275144) = 3.709463570275677
# f(2.8454158843448356) = 0.593842355835478
# f(2.773143092634202) = 0.0285402881796184
# f(2.7693029596247096) = 7.838698133211253e-05
# f(2.7692923543194023) = 5.96992677515118e-10
#       converged: True
#            flag: converged
#  function_calls: 30
#      iterations: 15
#            root: 2.7692923542386314
#          method: newton

# %% [markdown]
# Dibujar la trayectoria de las raíces
# * Pruebe 3 estimaciones iniciales diferentes

# %%
x0 = 100
root = newton(f, x0, fprime=fprime)
x = np.linspace(-3, 3, 400)
y = f(x)
plt.figure(figsize=(8, 6))
plt.plot(x, y, label="$x^3 - 3x^2 + x - 1$")
plt.axhline(0, color="black", linewidth=0.5)
plt.axvline(0, color="black", linewidth=0.5)
plt.scatter(root, f(root), color="red", zorder=5)  # Añadir la raíz al gráfico
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of the equation $x^3 - 3x^2 + x - 1$")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
print(f'La raíz aproximada es: {root}')
plt.show()
# Out:
# La raíz aproximada es: 2.7692923542386314

# %% [markdown]
# ¿Cómo ejecutar el código y evitar que dé error para toda estimación?

# %%
x0 = 100
root = newton(f, x0, fprime=fprime, disp= False, full_output=True)
print(f'')
print("La raíz aproximada es:", root)
# Out:
# La raíz aproximada es: (2.7692923542386314,       converged: True
#            flag: converged
#  function_calls: 30
#      iterations: 15
#            root: 2.7692923542386314
#          method: newton)

# %% [markdown]
# ## Valor de 5

# %% [markdown]
# Encontrar la o las raíces usando el método de Newton con Scipy

# %%
def f(x):
    return x**3 - 3*x**2 + x - 1
def fprime(x):
    return 3*x**2-6*x+1
x0 = 5
root = newton(f, x0, fprime=fprime)
print(f'')
print("La raíz aproximada es:", root)
# Out:
# La raíz aproximada es: 2.7692923542386314

# %% [markdown]
# Retornar las estimaciones visitadas por el algoritmo
# * Usando el parámetro args=() u otro método

# %%
points = []
x0 = 5
def f(x: float, points: list[float] = [], show: bool = False):
    y = x**3 - 3 * x**2 + x - 1
    points.append((x, y))
    if show:
        print(f"f({x}) = {y}")
        #pass
    return y
def f_prime(x, *args):
    return 3*x**2-6*x+1
x_r, output = newton(
    f, x0, fprime= f_prime, args=(points, True), maxiter=100, disp= False, full_output= True)
print(output)
x_points = [point[0] for point in points]
plt.figure(figsize=(8, 6))
plt.plot(x_points, "o-", label="x points")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of x points in points")
plt.xlabel("Index")
plt.ylabel("x value")
plt.legend()
plt.show()
# Out:
# f(5.0) = 54.0
# f(3.8260869565217392) = 14.919125503410864
# f(3.1467190137392356) = 3.5995072936479273
# f(2.842326277140092) = 0.5685088618057428
# f(2.7728476364392374) = 0.026344889781334313
# f(2.7693013974364495) = 6.684039393345387e-05
# f(2.76929235429736) = 4.3407455407873385e-10
#       converged: True
#            flag: converged
#  function_calls: 14
#      iterations: 7
#            root: 2.7692923542386314
#          method: newton

# %% [markdown]
# Dibujar la trayectoria de las raíces
# * Pruebe 3 estimaciones iniciales diferentes

# %%
x0 = 5
root = newton(f, x0, fprime=fprime)
x = np.linspace(-3, 3, 400)
y = f(x)
plt.figure(figsize=(8, 6))
plt.plot(x, y, label="$x^3 - 3x^2 + x - 1$")
plt.axhline(0, color="black", linewidth=0.5)
plt.axvline(0, color="black", linewidth=0.5)
plt.scatter(root, f(root), color="red", zorder=5)  
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of the equation $x^3 - 3x^2 + x - 1$")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
print(f'La raíz aproximada es: {root}')
plt.show()
# Out:
# La raíz aproximada es: 2.7692923542386314

# %% [markdown]
# ¿Cómo ejecutar el código y evitar que dé error para toda estimación?

# %%
x0 = 5
root = newton(f, x0, fprime=fprime, disp= False, full_output=True)
print(f'')
print("La raíz aproximada es:", root)
# Out:
# La raíz aproximada es: (2.7692923542386314,       converged: True
#            flag: converged
#  function_calls: 14
#      iterations: 7
#            root: 2.7692923542386314
#          method: newton)

# %% [markdown]
# ## Valor 2

# %% [markdown]
# Encontrar la o las raíces usando el método de Newton con Scipy

# %%
x0 = 1
root = newton(f, x0, fprime=fprime, disp= False, full_output=True)
print(f'')
print("La raíz aproximada es:", root)
# Out:
# La raíz aproximada es: (1.0,       converged: False
#            flag: convergence error
#  function_calls: 100
#      iterations: 50
#            root: 1.0
#          method: newton)

# %% [markdown]
# Retornar las estimaciones visitadas por el algoritmo
# * Usando el parámetro args=() u otro método

# %%
points = []
x0 = -1
def f(x: float, points: list[float] = [], show: bool = False):
    y = x**3 - 3 * x**2 + x - 1
    points.append((x, y))
    if show:
        #print(f"f({x}) = {y}")
        pass
    return y
def f_prime(x, *args):
    return 3*x**2-6*x+1
x_r, output = newton(
    f, x0, fprime= f_prime, args=(points, True), maxiter=100, disp= False, full_output= True)
print(output)
x_points = [point[0] for point in points]
plt.figure(figsize=(8, 6))
plt.plot(x_points, "o-", label="x points")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of x points in points")
plt.xlabel("Index")
plt.ylabel("x value")
plt.legend()
plt.show()
# Out:
#       converged: True
#            flag: converged
#  function_calls: 18
#      iterations: 9
#            root: 2.7692923542386314
#          method: newton

# %% [markdown]
# Dibujar la trayectoria de las raíces
#
# Pruebe 3 estimaciones iniciales diferentes

# %%
x0 = 1
root = newton(f, x0, fprime=fprime, disp= False, full_output=True)
print(root)
# Out:
# (1.0,       converged: False
#            flag: convergence error
#  function_calls: 100
#      iterations: 50
#            root: 1.0
#          method: newton)

# %% [markdown]
# ¿Cómo ejecutar el código y evitar que dé error para toda estimación?

# %%
x0 = 1
root = newton(f, x0, fprime=fprime, disp= False, full_output=True)
print(f'')
print("La raíz aproximada es:", root)
# Out:
# La raíz aproximada es: (1.0,       converged: False
#            flag: convergence error
#  function_calls: 100
#      iterations: 50
#            root: 1.0
#          method: newton)
